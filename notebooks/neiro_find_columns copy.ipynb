# %%
from itertools import combinations

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import swifter

# %% [markdown]
# # Подготовка датасета для загрузки в сеть

# %%
base_df = pd.read_csv('data/clean_frame.csv', index_col='ind')
base_df.columns
# Out:
# Index(['ID', 'Код_группы', 'Год_Поступления', 'Год_Окончания_УЗ', 'Пособие',
#        'Общежитие', 'Наличие_Матери', 'Наличие_Отца', 'Опекунство', 'Село',
#        'Иностранец', 'КодФакультета', 'СрБаллАттестата', 'Статус', 'male',
#        'female', 'sex_summ', 'birth_year_int', 'basis', 'language', 'country',
#        'region', 'city', 'parents_country'],
#       dtype='object')

# %% [markdown]
# ### Проверка и удаление отрицательных значений

# %%
base_df.isna().any().all()
# Out:
# False

# %%
base_df = base_df.fillna(0)

# %%
def get_accuracy(frame_to_train):
    train, test = train_test_split(frame_to_train, test_size=0.20)
    
    train_input = train.drop('Статус', axis=1)    
    train_output = train['Статус']

    test_input = test.drop('Статус', axis=1)
    test_output = test['Статус']

    clf = RandomForestClassifier(random_state=0)
    clf.fit(train_input, train_output)
    pred = clf.predict(test_input)
    return f1_score(test_output, pred, average='macro', zero_division = 0)

# %%
all_columns_list = base_df.columns.to_list()
all_columns_list.remove('ID')
all_columns_list.remove('Статус')
all_columns_list
# Out:
# ['Код_группы',
#  'Год_Поступления',
#  'Год_Окончания_УЗ',
#  'Пособие',
#  'Общежитие',
#  'Наличие_Матери',
#  'Наличие_Отца',
#  'Опекунство',
#  'Село',
#  'Иностранец',
#  'КодФакультета',
#  'СрБаллАттестата',
#  'male',
#  'female',
#  'sex_summ',
#  'birth_year_int',
#  'basis',
#  'language',
#  'country',
#  'region',
#  'city',
#  'parents_country']

# %%
elements_num = len(all_columns_list)
elements_num
# Out:
# 22

# %%
all_combinations = []
list_sizes = 0
for i in range(2, elements_num+1):
    curent_list = list(combinations(all_columns_list, i))
    list_sizes += len(curent_list)
    all_combinations = all_combinations + curent_list
len(all_combinations)
# Out:
# 4194281

# %%
all_combinations
# Out:
# [('Код_группы', 'Год_Поступления'),
#  ('Код_группы', 'Год_Окончания_УЗ'),
#  ('Код_группы', 'Пособие'),
#  ('Код_группы', 'Общежитие'),
#  ('Код_группы', 'Наличие_Матери'),
#  ('Код_группы', 'Наличие_Отца'),
#  ('Код_группы', 'Опекунство'),
#  ('Код_группы', 'Село'),
#  ('Код_группы', 'Иностранец'),
#  ('Код_группы', 'КодФакультета'),
#  ('Код_группы', 'СрБаллАттестата'),
#  ('Код_группы', 'male'),
#  ('Код_группы', 'female'),
#  ('Код_группы', 'sex_summ'),
#  ('Код_группы', 'birth_year_int'),
#  ('Код_группы', 'basis'),
#  ('Код_группы', 'language'),
#  ('Код_группы', 'country'),
#  ('Код_группы', 'region'),
#  ('Код_группы', 'city'),
#  ('Код_группы', 'parents_country'),
#  ('Год_Поступления', 'Год_Окончания_УЗ'),
#  ('Год_Поступления', 'Пособие'),
#  ('Год_Поступления', 'Общежитие'),
#  ('Год_Поступления', 'Наличие_Матери'),
#  ('Год_Поступления', 'Наличие_Отца'),
#  ('Год_Поступления', 'Опекунство'),
#  ('Год_Поступления', 'Село'),
#  ('Год_Поступления', 'Иностранец'),
#  ('Год_Поступления', 'КодФакультета'),
#  ('Год_Поступления', 'СрБаллАттестата'),
#  ('Год_Поступления', 'male'),
#  ('Год_Поступления', 'female'),
#  ('Год_Поступления', 'sex_summ'),
#  ('Год_Поступления', 'birth_year_int'),
#  ('Год_Поступления', 'basis'),
#  ('Год_Поступления', 'language'),
#  ('Год_Поступления', 'country'),
#  ('Год_Поступления', 'region'),
#  ('Год_Поступления', 'city'),
#  ('Год_Поступления', 'parents_country'),
#  ('Год_Окончания_УЗ', 'Пособие'),
#  ('Год_Окончания_УЗ', 'Общежитие'),
#  ('Год_Окончания_УЗ', 'Наличие_Матери'),
#  ('Год_Окончания_УЗ', 'Наличие_Отца'),
#  ('Год_Окончания_УЗ', 'Опекунство'),
#  ('Год_Окончания_УЗ', 'Село'),
#  ('Год_Окончания_УЗ', 'Иностранец'),
#  ('Год_Окончания_УЗ', 'КодФакультета'),
#  ('Год_Окончания_УЗ', 'СрБаллАттестата'),
#  ('Год_Окончания_УЗ', 'male'),
#  ('Год_Окончания_УЗ', 'female'),
#  ('Год_Окончания_УЗ', 'sex_summ'),
#  ('Год_Окончания_УЗ', 'birth_year_int'),
#  ('Год_Окончания_УЗ', 'basis'),
#  ('Год_Окончания_УЗ', 'language'),
#  ('Год_Окончания_УЗ', 'country'),
#  ('Год_Окончания_УЗ', 'region'),
#  ('Год_Окончания_УЗ', 'city'),
#  ('Год_Окончания_УЗ', 'parents_country'),
#  ('Пособие', 'Общежитие'),
#  ('Пособие', 'Наличие_Матери'),
#  ('Пособие', 'Наличие_Отца'),
#  ('Пособие', 'Опекунство'),
#  ('Пособие', 'Село'),
#  ('Пособие', 'Иностранец'),
#  ('Пособие', 'КодФакультета'),
#  ('Пособие', 'СрБаллАттестата'),
#  ('Пособие', 'male'),
#  ('Пособие', 'female'),
#  ('Пособие', 'sex_summ'),
#  ('Пособие', 'birth_year_int'),
#  ('Пособие', 'basis'),
#  ('Пособие', 'language'),
#  ('Пособие', 'country'),
#  ('Пособие', 'region'),
#  ('Пособие', 'city'),
#  ('Пособие', 'parents_country'),
#  ('Общежитие', 'Наличие_Матери'),
#  ('Общежитие', 'Наличие_Отца'),
#  ('Общежитие', 'Опекунство'),
#  ('Общежитие', 'Село'),
#  ('Общежитие', 'Иностранец'),
#  ('Общежитие', 'КодФакультета'),
#  ('Общежитие', 'СрБаллАттестата'),
#  ('Общежитие', 'male'),
#  ('Общежитие', 'female'),
#  ('Общежитие', 'sex_summ'),
#  ('Общежитие', 'birth_year_int'),
#  ('Общежитие', 'basis'),
#  ('Общежитие', 'language'),
#  ('Общежитие', 'country'),
#  ('Общежитие', 'region'),
#  ('Общежитие', 'city'),
#  ('Общежитие', 'parents_country'),
#  ('Наличие_Матери', 'Наличие_Отца'),
#  ('Наличие_Матери', 'Опекунство'),
#  ('Наличие_Матери', 'Село'),
#  ('Наличие_Матери', 'Иностранец'),
#  ('Наличие_Матери', 'КодФакультета'),
#  ('Наличие_Матери', 'СрБаллАттестата'),
#  ('Наличие_Матери', 'male'),
#  ('Наличие_Матери', 'female'),
#  ('Наличие_Матери', 'sex_summ'),
#  ('Наличие_Матери', 'birth_year_int'),
#  ('Наличие_Матери', 'basis'),
#  ('Наличие_Матери', 'language'),
#  ('Наличие_Матери', 'country'),
#  ('Наличие_Матери', 'region'),
#  ('Наличие_Матери', 'city'),
#  ('Наличие_Матери', 'parents_country'),
#  ('Наличие_Отца', 'Опекунство'),
#  ('Наличие_Отца', 'Село'),
#  ('Наличие_Отца', 'Иностранец'),
#  ('Наличие_Отца', 'КодФакультета'),
#  ('Наличие_Отца', 'СрБаллАттестата'),
#  ('Наличие_Отца', 'male'),
#  ('Наличие_Отца', 'female'),
#  ('Наличие_Отца', 'sex_summ'),
#  ('Наличие_Отца', 'birth_year_int'),
#  ('Наличие_Отца', 'basis'),
#  ('Наличие_Отца', 'language'),
#  ('Наличие_Отца', 'country'),
#  ('Наличие_Отца', 'region'),
#  ('Наличие_Отца', 'city'),
#  ('Наличие_Отца', 'parents_country'),
#  ('Опекунство', 'Село'),
#  ('Опекунство', 'Иностранец'),
#  ('Опекунство', 'КодФакультета'),
#  ('Опекунство', 'СрБаллАттестата'),
#  ('Опекунство', 'male'),
#  ('Опекунство', 'female'),
#  ('Опекунство', 'sex_summ'),
#  ('Опекунство', 'birth_year_int'),
#  ('Опекунство', 'basis'),
#  ('Опекунство', 'language'),
#  ('Опекунство', 'country'),
#  ('Опекунство', 'region'),
#  ('Опекунство', 'city'),
#  ('Опекунство', 'parents_country'),
#  ('Село', 'Иностранец'),
#  ('Село', 'КодФакультета'),
#  ('Село', 'СрБаллАттестата'),
#  ('Село', 'male'),
#  ('Село', 'female'),
#  ('Село', 'sex_summ'),
#  ('Село', 'birth_year_int'),
#  ('Село', 'basis'),
#  ('Село', 'language'),
#  ('Село', 'country'),
#  ('Село', 'region'),
#  ('Село', 'city'),
#  ('Село', 'parents_country'),
#  ('Иностранец', 'КодФакультета'),
#  ('Иностранец', 'СрБаллАттестата'),
#  ('Иностранец', 'male'),
#  ('Иностранец', 'female'),
#  ('Иностранец', 'sex_summ'),
#  ('Иностранец', 'birth_year_int'),
#  ('Иностранец', 'basis'),
#  ('Иностранец', 'language'),
#  ('Иностранец', 'country'),
#  ('Иностранец', 'region'),
#  ('Иностранец', 'city'),
#  ('Иностранец', 'parents_country'),
#  ('КодФакультета', 'СрБаллАттестата'),
#  ('КодФакультета', 'male'),
#  ('КодФакультета', 'female'),
#  ('КодФакультета', 'sex_summ'),
#  ('КодФакультета', 'birth_year_int'),
#  ('КодФакультета', 'basis'),
#  ('КодФакультета', 'language'),
#  ('КодФакультета', 'country'),
#  ('КодФакультета', 'region'),
#  ('КодФакультета', 'city'),
#  ('КодФакультета', 'parents_country'),
#  ('СрБаллАттестата', 'male'),
#  ('СрБаллАттестата', 'female'),
#  ('СрБаллАттестата', 'sex_summ'),
#  ('СрБаллАттестата', 'birth_year_int'),
#  ('СрБаллАттестата', 'basis'),
#  ('СрБаллАттестата', 'language'),
#  ('СрБаллАттестата', 'country'),
#  ('СрБаллАттестата', 'region'),
#  ('СрБаллАттестата', 'city'),
#  ('СрБаллАттестата', 'parents_country'),
#  ('male', 'female'),
#  ('male', 'sex_summ'),
#  ('male', 'birth_year_int'),
#  ('male', 'basis'),
#  ('male', 'language'),
#  ('male', 'country'),
#  ('male', 'region'),
#  ('male', 'city'),
#  ('male', 'parents_country'),
#  ('female', 'sex_summ'),
#  ('female', 'birth_year_int'),
#  ('female', 'basis'),
#  ('female', 'language'),
#  ('female', 'country'),
#  ('female', 'region'),
#  ('female', 'city'),
#  ('female', 'parents_country'),
#  ('sex_summ', 'birth_year_int'),
#  ('sex_summ', 'basis'),
#  ('sex_summ', 'language'),
#  ('sex_summ', 'country'),
#  ('sex_summ', 'region'),
#  ('sex_summ', 'city'),
#  ('sex_summ', 'parents_country'),
#  ('birth_year_int', 'basis'),
#  ('birth_year_int', 'language'),
#  ('birth_year_int', 'country'),
#  ('birth_year_int', 'region'),
#  ('birth_year_int', 'city'),
#  ('birth_year_int', 'parents_country'),
#  ('basis', 'language'),
#  ('basis', 'country'),
#  ('basis', 'region'),
#  ('basis', 'city'),
#  ('basis', 'parents_country'),
#  ('language', 'country'),
#  ('language', 'region'),
#  ('language', 'city'),
#  ('language', 'parents_country'),
#  ('country', 'region'),
#  ('country', 'city'),
#  ('country', 'parents_country'),
#  ('region', 'city'),
#  ('region', 'parents_country'),
#  ('city', 'parents_country'),
#  ('Код_группы', 'Год_Поступления', 'Год_Окончания_УЗ'),
#  ('Код_группы', 'Год_Поступления', 'Пособие'),
#  ('Код_группы', 'Год_Поступления', 'Общежитие'),
#  ('Код_группы', 'Год_Поступления', 'Наличие_Матери'),
#  ('Код_группы', 'Год_Поступления', 'Наличие_Отца'),
#  ('Код_группы', 'Год_Поступления', 'Опекунство'),
#  ('Код_группы', 'Год_Поступления', 'Село'),
#  ('Код_группы', 'Год_Поступления', 'Иностранец'),
#  ('Код_группы', 'Год_Поступления', 'КодФакультета'),
#  ('Код_группы', 'Год_Поступления', 'СрБаллАттестата'),
#  ('Код_группы', 'Год_Поступления', 'male'),
#  ('Код_группы', 'Год_Поступления', 'female'),
#  ('Код_группы', 'Год_Поступления', 'sex_summ'),
#  ('Код_группы', 'Год_Поступления', 'birth_year_int'),
#  ('Код_группы', 'Год_Поступления', 'basis'),
#  ('Код_группы', 'Год_Поступления', 'language'),
#  ('Код_группы', 'Год_Поступления', 'country'),
#  ('Код_группы', 'Год_Поступления', 'region'),
#  ('Код_группы', 'Год_Поступления', 'city'),
#  ('Код_группы', 'Год_Поступления', 'parents_country'),
#  ('Код_группы', 'Год_Окончания_УЗ', 'Пособие'),
#  ('Код_группы', 'Год_Окончания_УЗ', 'Общежитие'),
#  ('Код_группы', 'Год_Окончания_УЗ', 'Наличие_Матери'),
#  ('Код_группы', 'Год_Окончания_УЗ', 'Наличие_Отца'),
#  ('Код_группы', 'Год_Окончания_УЗ', 'Опекунство'),
#  ('Код_группы', 'Год_Окончания_УЗ', 'Село'),
#  ('Код_группы', 'Год_Окончания_УЗ', 'Иностранец'),
#  ('Код_группы', 'Год_Окончания_УЗ', 'КодФакультета'),
#  ('Код_группы', 'Год_Окончания_УЗ', 'СрБаллАттестата'),
#  ('Код_группы', 'Год_Окончания_УЗ', 'male'),
#  ('Код_группы', 'Год_Окончания_УЗ', 'female'),
#  ('Код_группы', 'Год_Окончания_УЗ', 'sex_summ'),
#  ('Код_группы', 'Год_Окончания_УЗ', 'birth_year_int'),
#  ('Код_группы', 'Год_Окончания_УЗ', 'basis'),
#  ('Код_группы', 'Год_Окончания_УЗ', 'language'),
#  ('Код_группы', 'Год_Окончания_УЗ', 'country'),
#  ('Код_группы', 'Год_Окончания_УЗ', 'region'),
#  ('Код_группы', 'Год_Окончания_УЗ', 'city'),
#  ('Код_группы', 'Год_Окончания_УЗ', 'parents_country'),
#  ('Код_группы', 'Пособие', 'Общежитие'),
#  ('Код_группы', 'Пособие', 'Наличие_Матери'),
#  ('Код_группы', 'Пособие', 'Наличие_Отца'),
#  ('Код_группы', 'Пособие', 'Опекунство'),
#  ('Код_группы', 'Пособие', 'Село'),
#  ('Код_группы', 'Пособие', 'Иностранец'),
#  ('Код_группы', 'Пособие', 'КодФакультета'),
#  ('Код_группы', 'Пособие', 'СрБаллАттестата'),
#  ('Код_группы', 'Пособие', 'male'),
#  ('Код_группы', 'Пособие', 'female'),
#  ('Код_группы', 'Пособие', 'sex_summ'),
#  ('Код_группы', 'Пособие', 'birth_year_int'),
#  ('Код_группы', 'Пособие', 'basis'),
#  ('Код_группы', 'Пособие', 'language'),
#  ('Код_группы', 'Пособие', 'country'),
#  ('Код_группы', 'Пособие', 'region'),
#  ('Код_группы', 'Пособие', 'city'),
#  ('Код_группы', 'Пособие', 'parents_country'),
#  ('Код_группы', 'Общежитие', 'Наличие_Матери'),
#  ('Код_группы', 'Общежитие', 'Наличие_Отца'),
#  ('Код_группы', 'Общежитие', 'Опекунство'),
#  ('Код_группы', 'Общежитие', 'Село'),
#  ('Код_группы', 'Общежитие', 'Иностранец'),
#  ('Код_группы', 'Общежитие', 'КодФакультета'),
#  ('Код_группы', 'Общежитие', 'СрБаллАттестата'),
#  ('Код_группы', 'Общежитие', 'male'),
#  ('Код_группы', 'Общежитие', 'female'),
#  ('Код_группы', 'Общежитие', 'sex_summ'),
#  ('Код_группы', 'Общежитие', 'birth_year_int'),
#  ('Код_группы', 'Общежитие', 'basis'),
#  ('Код_группы', 'Общежитие', 'language'),
#  ('Код_группы', 'Общежитие', 'country'),
#  ('Код_группы', 'Общежитие', 'region'),
#  ('Код_группы', 'Общежитие', 'city'),
#  ('Код_группы', 'Общежитие', 'parents_country'),
#  ('Код_группы', 'Наличие_Матери', 'Наличие_Отца'),
#  ('Код_группы', 'Наличие_Матери', 'Опекунство'),
#  ('Код_группы', 'Наличие_Матери', 'Село'),
#  ('Код_группы', 'Наличие_Матери', 'Иностранец'),
#  ('Код_группы', 'Наличие_Матери', 'КодФакультета'),
#  ('Код_группы', 'Наличие_Матери', 'СрБаллАттестата'),
#  ('Код_группы', 'Наличие_Матери', 'male'),
#  ('Код_группы', 'Наличие_Матери', 'female'),
#  ('Код_группы', 'Наличие_Матери', 'sex_summ'),
#  ('Код_группы', 'Наличие_Матери', 'birth_year_int'),
#  ('Код_группы', 'Наличие_Матери', 'basis'),
#  ('Код_группы', 'Наличие_Матери', 'language'),
#  ('Код_группы', 'Наличие_Матери', 'country'),
#  ('Код_группы', 'Наличие_Матери', 'region'),
#  ('Код_группы', 'Наличие_Матери', 'city'),
#  ('Код_группы', 'Наличие_Матери', 'parents_country'),
#  ('Код_группы', 'Наличие_Отца', 'Опекунство'),
#  ('Код_группы', 'Наличие_Отца', 'Село'),
#  ('Код_группы', 'Наличие_Отца', 'Иностранец'),
#  ('Код_группы', 'Наличие_Отца', 'КодФакультета'),
#  ('Код_группы', 'Наличие_Отца', 'СрБаллАттестата'),
#  ('Код_группы', 'Наличие_Отца', 'male'),
#  ('Код_группы', 'Наличие_Отца', 'female'),
#  ('Код_группы', 'Наличие_Отца', 'sex_summ'),
#  ('Код_группы', 'Наличие_Отца', 'birth_year_int'),
#  ('Код_группы', 'Наличие_Отца', 'basis'),
#  ('Код_группы', 'Наличие_Отца', 'language'),
#  ('Код_группы', 'Наличие_Отца', 'country'),
#  ('Код_группы', 'Наличие_Отца', 'region'),
#  ('Код_группы', 'Наличие_Отца', 'city'),
#  ('Код_группы', 'Наличие_Отца', 'parents_country'),
#  ('Код_группы', 'Опекунство', 'Село'),
#  ('Код_группы', 'Опекунство', 'Иностранец'),
#  ('Код_группы', 'Опекунство', 'КодФакультета'),
#  ('Код_группы', 'Опекунство', 'СрБаллАттестата'),
#  ('Код_группы', 'Опекунство', 'male'),
#  ('Код_группы', 'Опекунство', 'female'),
#  ('Код_группы', 'Опекунство', 'sex_summ'),
#  ('Код_группы', 'Опекунство', 'birth_year_int'),
#  ('Код_группы', 'Опекунство', 'basis'),
#  ('Код_группы', 'Опекунство', 'language'),
#  ('Код_группы', 'Опекунство', 'country'),
#  ('Код_группы', 'Опекунство', 'region'),
#  ('Код_группы', 'Опекунство', 'city'),
#  ('Код_группы', 'Опекунство', 'parents_country'),
#  ('Код_группы', 'Село', 'Иностранец'),
#  ('Код_группы', 'Село', 'КодФакультета'),
#  ('Код_группы', 'Село', 'СрБаллАттестата'),
#  ('Код_группы', 'Село', 'male'),
#  ('Код_группы', 'Село', 'female'),
#  ('Код_группы', 'Село', 'sex_summ'),
#  ('Код_группы', 'Село', 'birth_year_int'),
#  ('Код_группы', 'Село', 'basis'),
#  ('Код_группы', 'Село', 'language'),
#  ('Код_группы', 'Село', 'country'),
#  ('Код_группы', 'Село', 'region'),
#  ('Код_группы', 'Село', 'city'),
#  ('Код_группы', 'Село', 'parents_country'),
#  ('Код_группы', 'Иностранец', 'КодФакультета'),
#  ('Код_группы', 'Иностранец', 'СрБаллАттестата'),
#  ('Код_группы', 'Иностранец', 'male'),
#  ('Код_группы', 'Иностранец', 'female'),
#  ('Код_группы', 'Иностранец', 'sex_summ'),
#  ('Код_группы', 'Иностранец', 'birth_year_int'),
#  ('Код_группы', 'Иностранец', 'basis'),
#  ('Код_группы', 'Иностранец', 'language'),
#  ('Код_группы', 'Иностранец', 'country'),
#  ('Код_группы', 'Иностранец', 'region'),
#  ('Код_группы', 'Иностранец', 'city'),
#  ('Код_группы', 'Иностранец', 'parents_country'),
#  ('Код_группы', 'КодФакультета', 'СрБаллАттестата'),
#  ('Код_группы', 'КодФакультета', 'male'),
#  ('Код_группы', 'КодФакультета', 'female'),
#  ('Код_группы', 'КодФакультета', 'sex_summ'),
#  ('Код_группы', 'КодФакультета', 'birth_year_int'),
#  ('Код_группы', 'КодФакультета', 'basis'),
#  ('Код_группы', 'КодФакультета', 'language'),
#  ('Код_группы', 'КодФакультета', 'country'),
#  ('Код_группы', 'КодФакультета', 'region'),
#  ('Код_группы', 'КодФакультета', 'city'),
#  ('Код_группы', 'КодФакультета', 'parents_country'),
#  ('Код_группы', 'СрБаллАттестата', 'male'),
#  ('Код_группы', 'СрБаллАттестата', 'female'),
#  ('Код_группы', 'СрБаллАттестата', 'sex_summ'),
#  ('Код_группы', 'СрБаллАттестата', 'birth_year_int'),
#  ('Код_группы', 'СрБаллАттестата', 'basis'),
#  ('Код_группы', 'СрБаллАттестата', 'language'),
#  ('Код_группы', 'СрБаллАттестата', 'country'),
#  ('Код_группы', 'СрБаллАттестата', 'region'),
#  ('Код_группы', 'СрБаллАттестата', 'city'),
#  ('Код_группы', 'СрБаллАттестата', 'parents_country'),
#  ('Код_группы', 'male', 'female'),
#  ('Код_группы', 'male', 'sex_summ'),
#  ('Код_группы', 'male', 'birth_year_int'),
#  ('Код_группы', 'male', 'basis'),
#  ('Код_группы', 'male', 'language'),
#  ('Код_группы', 'male', 'country'),
#  ('Код_группы', 'male', 'region'),
#  ('Код_группы', 'male', 'city'),
#  ('Код_группы', 'male', 'parents_country'),
#  ('Код_группы', 'female', 'sex_summ'),
#  ('Код_группы', 'female', 'birth_year_int'),
#  ('Код_группы', 'female', 'basis'),
#  ('Код_группы', 'female', 'language'),
#  ('Код_группы', 'female', 'country'),
#  ('Код_группы', 'female', 'region'),
#  ('Код_группы', 'female', 'city'),
#  ('Код_группы', 'female', 'parents_country'),
#  ('Код_группы', 'sex_summ', 'birth_year_int'),
#  ('Код_группы', 'sex_summ', 'basis'),
#  ('Код_группы', 'sex_summ', 'language'),
#  ('Код_группы', 'sex_summ', 'country'),
#  ('Код_группы', 'sex_summ', 'region'),
#  ('Код_группы', 'sex_summ', 'city'),
#  ('Код_группы', 'sex_summ', 'parents_country'),
#  ('Код_группы', 'birth_year_int', 'basis'),
#  ('Код_группы', 'birth_year_int', 'language'),
#  ('Код_группы', 'birth_year_int', 'country'),
#  ('Код_группы', 'birth_year_int', 'region'),
#  ('Код_группы', 'birth_year_int', 'city'),
#  ('Код_группы', 'birth_year_int', 'parents_country'),
#  ('Код_группы', 'basis', 'language'),
#  ('Код_группы', 'basis', 'country'),
#  ('Код_группы', 'basis', 'region'),
#  ('Код_группы', 'basis', 'city'),
#  ('Код_группы', 'basis', 'parents_country'),
#  ('Код_группы', 'language', 'country'),
#  ('Код_группы', 'language', 'region'),
#  ('Код_группы', 'language', 'city'),
#  ('Код_группы', 'language', 'parents_country'),
#  ('Код_группы', 'country', 'region'),
#  ('Код_группы', 'country', 'city'),
#  ('Код_группы', 'country', 'parents_country'),
#  ('Код_группы', 'region', 'city'),
#  ('Код_группы', 'region', 'parents_country'),
#  ('Код_группы', 'city', 'parents_country'),
#  ('Год_Поступления', 'Год_Окончания_УЗ', 'Пособие'),
#  ('Год_Поступления', 'Год_Окончания_УЗ', 'Общежитие'),
#  ('Год_Поступления', 'Год_Окончания_УЗ', 'Наличие_Матери'),
#  ('Год_Поступления', 'Год_Окончания_УЗ', 'Наличие_Отца'),
#  ('Год_Поступления', 'Год_Окончания_УЗ', 'Опекунство'),
#  ('Год_Поступления', 'Год_Окончания_УЗ', 'Село'),
#  ('Год_Поступления', 'Год_Окончания_УЗ', 'Иностранец'),
#  ('Год_Поступления', 'Год_Окончания_УЗ', 'КодФакультета'),
#  ('Год_Поступления', 'Год_Окончания_УЗ', 'СрБаллАттестата'),
#  ('Год_Поступления', 'Год_Окончания_УЗ', 'male'),
#  ('Год_Поступления', 'Год_Окончания_УЗ', 'female'),
#  ('Год_Поступления', 'Год_Окончания_УЗ', 'sex_summ'),
#  ('Год_Поступления', 'Год_Окончания_УЗ', 'birth_year_int'),
#  ('Год_Поступления', 'Год_Окончания_УЗ', 'basis'),
#  ('Год_Поступления', 'Год_Окончания_УЗ', 'language'),
#  ('Год_Поступления', 'Год_Окончания_УЗ', 'country'),
#  ('Год_Поступления', 'Год_Окончания_УЗ', 'region'),
#  ('Год_Поступления', 'Год_Окончания_УЗ', 'city'),
#  ('Год_Поступления', 'Год_Окончания_УЗ', 'parents_country'),
#  ('Год_Поступления', 'Пособие', 'Общежитие'),
#  ('Год_Поступления', 'Пособие', 'Наличие_Матери'),
#  ('Год_Поступления', 'Пособие', 'Наличие_Отца'),
#  ('Год_Поступления', 'Пособие', 'Опекунство'),
#  ('Год_Поступления', 'Пособие', 'Село'),
#  ('Год_Поступления', 'Пособие', 'Иностранец'),
#  ('Год_Поступления', 'Пособие', 'КодФакультета'),
#  ('Год_Поступления', 'Пособие', 'СрБаллАттестата'),
#  ('Год_Поступления', 'Пособие', 'male'),
#  ('Год_Поступления', 'Пособие', 'female'),
#  ('Год_Поступления', 'Пособие', 'sex_summ'),
#  ('Год_Поступления', 'Пособие', 'birth_year_int'),
#  ('Год_Поступления', 'Пособие', 'basis'),
#  ('Год_Поступления', 'Пособие', 'language'),
#  ('Год_Поступления', 'Пособие', 'country'),
#  ('Год_Поступления', 'Пособие', 'region'),
#  ('Год_Поступления', 'Пособие', 'city'),
#  ('Год_Поступления', 'Пособие', 'parents_country'),
#  ('Год_Поступления', 'Общежитие', 'Наличие_Матери'),
#  ('Год_Поступления', 'Общежитие', 'Наличие_Отца'),
#  ('Год_Поступления', 'Общежитие', 'Опекунство'),
#  ('Год_Поступления', 'Общежитие', 'Село'),
#  ('Год_Поступления', 'Общежитие', 'Иностранец'),
#  ('Год_Поступления', 'Общежитие', 'КодФакультета'),
#  ('Год_Поступления', 'Общежитие', 'СрБаллАттестата'),
#  ('Год_Поступления', 'Общежитие', 'male'),
#  ('Год_Поступления', 'Общежитие', 'female'),
#  ('Год_Поступления', 'Общежитие', 'sex_summ'),
#  ('Год_Поступления', 'Общежитие', 'birth_year_int'),
#  ('Год_Поступления', 'Общежитие', 'basis'),
#  ('Год_Поступления', 'Общежитие', 'language'),
#  ('Год_Поступления', 'Общежитие', 'country'),
#  ('Год_Поступления', 'Общежитие', 'region'),
#  ('Год_Поступления', 'Общежитие', 'city'),
#  ('Год_Поступления', 'Общежитие', 'parents_country'),
#  ('Год_Поступления', 'Наличие_Матери', 'Наличие_Отца'),
#  ('Год_Поступления', 'Наличие_Матери', 'Опекунство'),
#  ('Год_Поступления', 'Наличие_Матери', 'Село'),
#  ('Год_Поступления', 'Наличие_Матери', 'Иностранец'),
#  ('Год_Поступления', 'Наличие_Матери', 'КодФакультета'),
#  ('Год_Поступления', 'Наличие_Матери', 'СрБаллАттестата'),
#  ('Год_Поступления', 'Наличие_Матери', 'male'),
#  ('Год_Поступления', 'Наличие_Матери', 'female'),
#  ('Год_Поступления', 'Наличие_Матери', 'sex_summ'),
#  ('Год_Поступления', 'Наличие_Матери', 'birth_year_int'),
#  ('Год_Поступления', 'Наличие_Матери', 'basis'),
#  ('Год_Поступления', 'Наличие_Матери', 'language'),
#  ('Год_Поступления', 'Наличие_Матери', 'country'),
#  ('Год_Поступления', 'Наличие_Матери', 'region'),
#  ('Год_Поступления', 'Наличие_Матери', 'city'),
#  ('Год_Поступления', 'Наличие_Матери', 'parents_country'),
#  ('Год_Поступления', 'Наличие_Отца', 'Опекунство'),
#  ('Год_Поступления', 'Наличие_Отца', 'Село'),
#  ('Год_Поступления', 'Наличие_Отца', 'Иностранец'),
#  ('Год_Поступления', 'Наличие_Отца', 'КодФакультета'),
#  ('Год_Поступления', 'Наличие_Отца', 'СрБаллАттестата'),
#  ('Год_Поступления', 'Наличие_Отца', 'male'),
#  ('Год_Поступления', 'Наличие_Отца', 'female'),
#  ('Год_Поступления', 'Наличие_Отца', 'sex_summ'),
#  ('Год_Поступления', 'Наличие_Отца', 'birth_year_int'),
#  ('Год_Поступления', 'Наличие_Отца', 'basis'),
#  ('Год_Поступления', 'Наличие_Отца', 'language'),
#  ('Год_Поступления', 'Наличие_Отца', 'country'),
#  ('Год_Поступления', 'Наличие_Отца', 'region'),
#  ('Год_Поступления', 'Наличие_Отца', 'city'),
#  ('Год_Поступления', 'Наличие_Отца', 'parents_country'),
#  ('Год_Поступления', 'Опекунство', 'Село'),
#  ('Год_Поступления', 'Опекунство', 'Иностранец'),
#  ('Год_Поступления', 'Опекунство', 'КодФакультета'),
#  ('Год_Поступления', 'Опекунство', 'СрБаллАттестата'),
#  ('Год_Поступления', 'Опекунство', 'male'),
#  ('Год_Поступления', 'Опекунство', 'female'),
#  ('Год_Поступления', 'Опекунство', 'sex_summ'),
#  ('Год_Поступления', 'Опекунство', 'birth_year_int'),
#  ('Год_Поступления', 'Опекунство', 'basis'),
#  ('Год_Поступления', 'Опекунство', 'language'),
#  ('Год_Поступления', 'Опекунство', 'country'),
#  ('Год_Поступления', 'Опекунство', 'region'),
#  ('Год_Поступления', 'Опекунство', 'city'),
#  ('Год_Поступления', 'Опекунство', 'parents_country'),
#  ('Год_Поступления', 'Село', 'Иностранец'),
#  ('Год_Поступления', 'Село', 'КодФакультета'),
#  ('Год_Поступления', 'Село', 'СрБаллАттестата'),
#  ('Год_Поступления', 'Село', 'male'),
#  ('Год_Поступления', 'Село', 'female'),
#  ('Год_Поступления', 'Село', 'sex_summ'),
#  ('Год_Поступления', 'Село', 'birth_year_int'),
#  ('Год_Поступления', 'Село', 'basis'),
#  ('Год_Поступления', 'Село', 'language'),
#  ('Год_Поступления', 'Село', 'country'),
#  ('Год_Поступления', 'Село', 'region'),
#  ('Год_Поступления', 'Село', 'city'),
#  ('Год_Поступления', 'Село', 'parents_country'),
#  ('Год_Поступления', 'Иностранец', 'КодФакультета'),
#  ('Год_Поступления', 'Иностранец', 'СрБаллАттестата'),
#  ('Год_Поступления', 'Иностранец', 'male'),
#  ('Год_Поступления', 'Иностранец', 'female'),
#  ('Год_Поступления', 'Иностранец', 'sex_summ'),
#  ('Год_Поступления', 'Иностранец', 'birth_year_int'),
#  ('Год_Поступления', 'Иностранец', 'basis'),
#  ('Год_Поступления', 'Иностранец', 'language'),
#  ('Год_Поступления', 'Иностранец', 'country'),
#  ('Год_Поступления', 'Иностранец', 'region'),
#  ('Год_Поступления', 'Иностранец', 'city'),
#  ('Год_Поступления', 'Иностранец', 'parents_country'),
#  ('Год_Поступления', 'КодФакультета', 'СрБаллАттестата'),
#  ('Год_Поступления', 'КодФакультета', 'male'),
#  ('Год_Поступления', 'КодФакультета', 'female'),
#  ('Год_Поступления', 'КодФакультета', 'sex_summ'),
#  ('Год_Поступления', 'КодФакультета', 'birth_year_int'),
#  ('Год_Поступления', 'КодФакультета', 'basis'),
#  ('Год_Поступления', 'КодФакультета', 'language'),
#  ('Год_Поступления', 'КодФакультета', 'country'),
#  ('Год_Поступления', 'КодФакультета', 'region'),
#  ('Год_Поступления', 'КодФакультета', 'city'),
#  ('Год_Поступления', 'КодФакультета', 'parents_country'),
#  ('Год_Поступления', 'СрБаллАттестата', 'male'),
#  ('Год_Поступления', 'СрБаллАттестата', 'female'),
#  ('Год_Поступления', 'СрБаллАттестата', 'sex_summ'),
#  ('Год_Поступления', 'СрБаллАттестата', 'birth_year_int'),
#  ('Год_Поступления', 'СрБаллАттестата', 'basis'),
#  ('Год_Поступления', 'СрБаллАттестата', 'language'),
#  ('Год_Поступления', 'СрБаллАттестата', 'country'),
#  ('Год_Поступления', 'СрБаллАттестата', 'region'),
#  ('Год_Поступления', 'СрБаллАттестата', 'city'),
#  ('Год_Поступления', 'СрБаллАттестата', 'parents_country'),
#  ('Год_Поступления', 'male', 'female'),
#  ('Год_Поступления', 'male', 'sex_summ'),
#  ('Год_Поступления', 'male', 'birth_year_int'),
#  ('Год_Поступления', 'male', 'basis'),
#  ('Год_Поступления', 'male', 'language'),
#  ('Год_Поступления', 'male', 'country'),
#  ('Год_Поступления', 'male', 'region'),
#  ('Год_Поступления', 'male', 'city'),
#  ('Год_Поступления', 'male', 'parents_country'),
#  ('Год_Поступления', 'female', 'sex_summ'),
#  ('Год_Поступления', 'female', 'birth_year_int'),
#  ('Год_Поступления', 'female', 'basis'),
#  ('Год_Поступления', 'female', 'language'),
#  ('Год_Поступления', 'female', 'country'),
#  ('Год_Поступления', 'female', 'region'),
#  ('Год_Поступления', 'female', 'city'),
#  ('Год_Поступления', 'female', 'parents_country'),
#  ('Год_Поступления', 'sex_summ', 'birth_year_int'),
#  ('Год_Поступления', 'sex_summ', 'basis'),
#  ('Год_Поступления', 'sex_summ', 'language'),
#  ('Год_Поступления', 'sex_summ', 'country'),
#  ('Год_Поступления', 'sex_summ', 'region'),
#  ('Год_Поступления', 'sex_summ', 'city'),
#  ('Год_Поступления', 'sex_summ', 'parents_country'),
#  ('Год_Поступления', 'birth_year_int', 'basis'),
#  ('Год_Поступления', 'birth_year_int', 'language'),
#  ('Год_Поступления', 'birth_year_int', 'country'),
#  ('Год_Поступления', 'birth_year_int', 'region'),
#  ('Год_Поступления', 'birth_year_int', 'city'),
#  ('Год_Поступления', 'birth_year_int', 'parents_country'),
#  ('Год_Поступления', 'basis', 'language'),
#  ('Год_Поступления', 'basis', 'country'),
#  ('Год_Поступления', 'basis', 'region'),
#  ('Год_Поступления', 'basis', 'city'),
#  ('Год_Поступления', 'basis', 'parents_country'),
#  ('Год_Поступления', 'language', 'country'),
#  ('Год_Поступления', 'language', 'region'),
#  ('Год_Поступления', 'language', 'city'),
#  ('Год_Поступления', 'language', 'parents_country'),
#  ('Год_Поступления', 'country', 'region'),
#  ('Год_Поступления', 'country', 'city'),
#  ('Год_Поступления', 'country', 'parents_country'),
#  ('Год_Поступления', 'region', 'city'),
#  ('Год_Поступления', 'region', 'parents_country'),
#  ('Год_Поступления', 'city', 'parents_country'),
#  ('Год_Окончания_УЗ', 'Пособие', 'Общежитие'),
#  ('Год_Окончания_УЗ', 'Пособие', 'Наличие_Матери'),
#  ('Год_Окончания_УЗ', 'Пособие', 'Наличие_Отца'),
#  ('Год_Окончания_УЗ', 'Пособие', 'Опекунство'),
#  ('Год_Окончания_УЗ', 'Пособие', 'Село'),
#  ('Год_Окончания_УЗ', 'Пособие', 'Иностранец'),
#  ('Год_Окончания_УЗ', 'Пособие', 'КодФакультета'),
#  ('Год_Окончания_УЗ', 'Пособие', 'СрБаллАттестата'),
#  ('Год_Окончания_УЗ', 'Пособие', 'male'),
#  ('Год_Окончания_УЗ', 'Пособие', 'female'),
#  ('Год_Окончания_УЗ', 'Пособие', 'sex_summ'),
#  ('Год_Окончания_УЗ', 'Пособие', 'birth_year_int'),
#  ('Год_Окончания_УЗ', 'Пособие', 'basis'),
#  ('Год_Окончания_УЗ', 'Пособие', 'language'),
#  ('Год_Окончания_УЗ', 'Пособие', 'country'),
#  ('Год_Окончания_УЗ', 'Пособие', 'region'),
#  ('Год_Окончания_УЗ', 'Пособие', 'city'),
#  ('Год_Окончания_УЗ', 'Пособие', 'parents_country'),
#  ('Год_Окончания_УЗ', 'Общежитие', 'Наличие_Матери'),
#  ('Год_Окончания_УЗ', 'Общежитие', 'Наличие_Отца'),
#  ('Год_Окончания_УЗ', 'Общежитие', 'Опекунство'),
#  ('Год_Окончания_УЗ', 'Общежитие', 'Село'),
#  ('Год_Окончания_УЗ', 'Общежитие', 'Иностранец'),
#  ('Год_Окончания_УЗ', 'Общежитие', 'КодФакультета'),
#  ('Год_Окончания_УЗ', 'Общежитие', 'СрБаллАттестата'),
#  ('Год_Окончания_УЗ', 'Общежитие', 'male'),
#  ('Год_Окончания_УЗ', 'Общежитие', 'female'),
#  ('Год_Окончания_УЗ', 'Общежитие', 'sex_summ'),
#  ('Год_Окончания_УЗ', 'Общежитие', 'birth_year_int'),
#  ('Год_Окончания_УЗ', 'Общежитие', 'basis'),
#  ('Год_Окончания_УЗ', 'Общежитие', 'language'),
#  ('Год_Окончания_УЗ', 'Общежитие', 'country'),
#  ('Год_Окончания_УЗ', 'Общежитие', 'region'),
#  ('Год_Окончания_УЗ', 'Общежитие', 'city'),
#  ('Год_Окончания_УЗ', 'Общежитие', 'parents_country'),
#  ('Год_Окончания_УЗ', 'Наличие_Матери', 'Наличие_Отца'),
#  ('Год_Окончания_УЗ', 'Наличие_Матери', 'Опекунство'),
#  ('Год_Окончания_УЗ', 'Наличие_Матери', 'Село'),
#  ('Год_Окончания_УЗ', 'Наличие_Матери', 'Иностранец'),
#  ('Год_Окончания_УЗ', 'Наличие_Матери', 'КодФакультета'),
#  ('Год_Окончания_УЗ', 'Наличие_Матери', 'СрБаллАттестата'),
#  ('Год_Окончания_УЗ', 'Наличие_Матери', 'male'),
#  ('Год_Окончания_УЗ', 'Наличие_Матери', 'female'),
#  ('Год_Окончания_УЗ', 'Наличие_Матери', 'sex_summ'),
#  ('Год_Окончания_УЗ', 'Наличие_Матери', 'birth_year_int'),
#  ('Год_Окончания_УЗ', 'Наличие_Матери', 'basis'),
#  ('Год_Окончания_УЗ', 'Наличие_Матери', 'language'),
#  ('Год_Окончания_УЗ', 'Наличие_Матери', 'country'),
#  ('Год_Окончания_УЗ', 'Наличие_Матери', 'region'),
#  ('Год_Окончания_УЗ', 'Наличие_Матери', 'city'),
#  ('Год_Окончания_УЗ', 'Наличие_Матери', 'parents_country'),
#  ('Год_Окончания_УЗ', 'Наличие_Отца', 'Опекунство'),
#  ('Год_Окончания_УЗ', 'Наличие_Отца', 'Село'),
#  ('Год_Окончания_УЗ', 'Наличие_Отца', 'Иностранец'),
#  ('Год_Окончания_УЗ', 'Наличие_Отца', 'КодФакультета'),
#  ('Год_Окончания_УЗ', 'Наличие_Отца', 'СрБаллАттестата'),
#  ('Год_Окончания_УЗ', 'Наличие_Отца', 'male'),
#  ('Год_Окончания_УЗ', 'Наличие_Отца', 'female'),
#  ('Год_Окончания_УЗ', 'Наличие_Отца', 'sex_summ'),
#  ('Год_Окончания_УЗ', 'Наличие_Отца', 'birth_year_int'),
#  ('Год_Окончания_УЗ', 'Наличие_Отца', 'basis'),
#  ('Год_Окончания_УЗ', 'Наличие_Отца', 'language'),
#  ('Год_Окончания_УЗ', 'Наличие_Отца', 'country'),
#  ('Год_Окончания_УЗ', 'Наличие_Отца', 'region'),
#  ('Год_Окончания_УЗ', 'Наличие_Отца', 'city'),
#  ('Год_Окончания_УЗ', 'Наличие_Отца', 'parents_country'),
#  ('Год_Окончания_УЗ', 'Опекунство', 'Село'),
#  ('Год_Окончания_УЗ', 'Опекунство', 'Иностранец'),
#  ('Год_Окончания_УЗ', 'Опекунство', 'КодФакультета'),
#  ('Год_Окончания_УЗ', 'Опекунство', 'СрБаллАттестата'),
#  ('Год_Окончания_УЗ', 'Опекунство', 'male'),
#  ('Год_Окончания_УЗ', 'Опекунство', 'female'),
#  ('Год_Окончания_УЗ', 'Опекунство', 'sex_summ'),
#  ('Год_Окончания_УЗ', 'Опекунство', 'birth_year_int'),
#  ('Год_Окончания_УЗ', 'Опекунство', 'basis'),
#  ('Год_Окончания_УЗ', 'Опекунство', 'language'),
#  ('Год_Окончания_УЗ', 'Опекунство', 'country'),
#  ('Год_Окончания_УЗ', 'Опекунство', 'region'),
#  ('Год_Окончания_УЗ', 'Опекунство', 'city'),
#  ('Год_Окончания_УЗ', 'Опекунство', 'parents_country'),
#  ('Год_Окончания_УЗ', 'Село', 'Иностранец'),
#  ('Год_Окончания_УЗ', 'Село', 'КодФакультета'),
#  ('Год_Окончания_УЗ', 'Село', 'СрБаллАттестата'),
#  ('Год_Окончания_УЗ', 'Село', 'male'),
#  ('Год_Окончания_УЗ', 'Село', 'female'),
#  ('Год_Окончания_УЗ', 'Село', 'sex_summ'),
#  ('Год_Окончания_УЗ', 'Село', 'birth_year_int'),
#  ('Год_Окончания_УЗ', 'Село', 'basis'),
#  ('Год_Окончания_УЗ', 'Село', 'language'),
#  ('Год_Окончания_УЗ', 'Село', 'country'),
#  ('Год_Окончания_УЗ', 'Село', 'region'),
#  ('Год_Окончания_УЗ', 'Село', 'city'),
#  ('Год_Окончания_УЗ', 'Село', 'parents_country'),
#  ('Год_Окончания_УЗ', 'Иностранец', 'КодФакультета'),
#  ('Год_Окончания_УЗ', 'Иностранец', 'СрБаллАттестата'),
#  ('Год_Окончания_УЗ', 'Иностранец', 'male'),
#  ('Год_Окончания_УЗ', 'Иностранец', 'female'),
#  ('Год_Окончания_УЗ', 'Иностранец', 'sex_summ'),
#  ('Год_Окончания_УЗ', 'Иностранец', 'birth_year_int'),
#  ('Год_Окончания_УЗ', 'Иностранец', 'basis'),
#  ('Год_Окончания_УЗ', 'Иностранец', 'language'),
#  ('Год_Окончания_УЗ', 'Иностранец', 'country'),
#  ('Год_Окончания_УЗ', 'Иностранец', 'region'),
#  ('Год_Окончания_УЗ', 'Иностранец', 'city'),
#  ('Год_Окончания_УЗ', 'Иностранец', 'parents_country'),
#  ('Год_Окончания_УЗ', 'КодФакультета', 'СрБаллАттестата'),
#  ('Год_Окончания_УЗ', 'КодФакультета', 'male'),
#  ('Год_Окончания_УЗ', 'КодФакультета', 'female'),
#  ('Год_Окончания_УЗ', 'КодФакультета', 'sex_summ'),
#  ('Год_Окончания_УЗ', 'КодФакультета', 'birth_year_int'),
#  ('Год_Окончания_УЗ', 'КодФакультета', 'basis'),
#  ('Год_Окончания_УЗ', 'КодФакультета', 'language'),
#  ('Год_Окончания_УЗ', 'КодФакультета', 'country'),
#  ('Год_Окончания_УЗ', 'КодФакультета', 'region'),
#  ('Год_Окончания_УЗ', 'КодФакультета', 'city'),
#  ('Год_Окончания_УЗ', 'КодФакультета', 'parents_country'),
#  ('Год_Окончания_УЗ', 'СрБаллАттестата', 'male'),
#  ('Год_Окончания_УЗ', 'СрБаллАттестата', 'female'),
#  ('Год_Окончания_УЗ', 'СрБаллАттестата', 'sex_summ'),
#  ('Год_Окончания_УЗ', 'СрБаллАттестата', 'birth_year_int'),
#  ('Год_Окончания_УЗ', 'СрБаллАттестата', 'basis'),
#  ('Год_Окончания_УЗ', 'СрБаллАттестата', 'language'),
#  ('Год_Окончания_УЗ', 'СрБаллАттестата', 'country'),
#  ('Год_Окончания_УЗ', 'СрБаллАттестата', 'region'),
#  ('Год_Окончания_УЗ', 'СрБаллАттестата', 'city'),
#  ('Год_Окончания_УЗ', 'СрБаллАттестата', 'parents_country'),
#  ('Год_Окончания_УЗ', 'male', 'female'),
#  ('Год_Окончания_УЗ', 'male', 'sex_summ'),
#  ('Год_Окончания_УЗ', 'male', 'birth_year_int'),
#  ('Год_Окончания_УЗ', 'male', 'basis'),
#  ('Год_Окончания_УЗ', 'male', 'language'),
#  ('Год_Окончания_УЗ', 'male', 'country'),
#  ('Год_Окончания_УЗ', 'male', 'region'),
#  ('Год_Окончания_УЗ', 'male', 'city'),
#  ('Год_Окончания_УЗ', 'male', 'parents_country'),
#  ('Год_Окончания_УЗ', 'female', 'sex_summ'),
#  ('Год_Окончания_УЗ', 'female', 'birth_year_int'),
#  ('Год_Окончания_УЗ', 'female', 'basis'),
#  ('Год_Окончания_УЗ', 'female', 'language'),
#  ('Год_Окончания_УЗ', 'female', 'country'),
#  ('Год_Окончания_УЗ', 'female', 'region'),
#  ('Год_Окончания_УЗ', 'female', 'city'),
#  ('Год_Окончания_УЗ', 'female', 'parents_country'),
#  ('Год_Окончания_УЗ', 'sex_summ', 'birth_year_int'),
#  ('Год_Окончания_УЗ', 'sex_summ', 'basis'),
#  ('Год_Окончания_УЗ', 'sex_summ', 'language'),
#  ('Год_Окончания_УЗ', 'sex_summ', 'country'),
#  ('Год_Окончания_УЗ', 'sex_summ', 'region'),
#  ('Год_Окончания_УЗ', 'sex_summ', 'city'),
#  ('Год_Окончания_УЗ', 'sex_summ', 'parents_country'),
#  ('Год_Окончания_УЗ', 'birth_year_int', 'basis'),
#  ('Год_Окончания_УЗ', 'birth_year_int', 'language'),
#  ('Год_Окончания_УЗ', 'birth_year_int', 'country'),
#  ('Год_Окончания_УЗ', 'birth_year_int', 'region'),
#  ('Год_Окончания_УЗ', 'birth_year_int', 'city'),
#  ('Год_Окончания_УЗ', 'birth_year_int', 'parents_country'),
#  ('Год_Окончания_УЗ', 'basis', 'language'),
#  ('Год_Окончания_УЗ', 'basis', 'country'),
#  ('Год_Окончания_УЗ', 'basis', 'region'),
#  ('Год_Окончания_УЗ', 'basis', 'city'),
#  ('Год_Окончания_УЗ', 'basis', 'parents_country'),
#  ('Год_Окончания_УЗ', 'language', 'country'),
#  ('Год_Окончания_УЗ', 'language', 'region'),
#  ('Год_Окончания_УЗ', 'language', 'city'),
#  ('Год_Окончания_УЗ', 'language', 'parents_country'),
#  ('Год_Окончания_УЗ', 'country', 'region'),
#  ('Год_Окончания_УЗ', 'country', 'city'),
#  ('Год_Окончания_УЗ', 'country', 'parents_country'),
#  ('Год_Окончания_УЗ', 'region', 'city'),
#  ('Год_Окончания_УЗ', 'region', 'parents_country'),
#  ('Год_Окончания_УЗ', 'city', 'parents_country'),
#  ('Пособие', 'Общежитие', 'Наличие_Матери'),
#  ('Пособие', 'Общежитие', 'Наличие_Отца'),
#  ('Пособие', 'Общежитие', 'Опекунство'),
#  ('Пособие', 'Общежитие', 'Село'),
#  ('Пособие', 'Общежитие', 'Иностранец'),
#  ('Пособие', 'Общежитие', 'КодФакультета'),
#  ('Пособие', 'Общежитие', 'СрБаллАттестата'),
#  ('Пособие', 'Общежитие', 'male'),
#  ('Пособие', 'Общежитие', 'female'),
#  ('Пособие', 'Общежитие', 'sex_summ'),
#  ('Пособие', 'Общежитие', 'birth_year_int'),
#  ('Пособие', 'Общежитие', 'basis'),
#  ('Пособие', 'Общежитие', 'language'),
#  ('Пособие', 'Общежитие', 'country'),
#  ('Пособие', 'Общежитие', 'region'),
#  ('Пособие', 'Общежитие', 'city'),
#  ('Пособие', 'Общежитие', 'parents_country'),
#  ('Пособие', 'Наличие_Матери', 'Наличие_Отца'),
#  ('Пособие', 'Наличие_Матери', 'Опекунство'),
#  ('Пособие', 'Наличие_Матери', 'Село'),
#  ('Пособие', 'Наличие_Матери', 'Иностранец'),
#  ('Пособие', 'Наличие_Матери', 'КодФакультета'),
#  ('Пособие', 'Наличие_Матери', 'СрБаллАттестата'),
#  ('Пособие', 'Наличие_Матери', 'male'),
#  ('Пособие', 'Наличие_Матери', 'female'),
#  ('Пособие', 'Наличие_Матери', 'sex_summ'),
#  ('Пособие', 'Наличие_Матери', 'birth_year_int'),
#  ('Пособие', 'Наличие_Матери', 'basis'),
#  ('Пособие', 'Наличие_Матери', 'language'),
#  ('Пособие', 'Наличие_Матери', 'country'),
#  ('Пособие', 'Наличие_Матери', 'region'),
#  ('Пособие', 'Наличие_Матери', 'city'),
#  ('Пособие', 'Наличие_Матери', 'parents_country'),
#  ('Пособие', 'Наличие_Отца', 'Опекунство'),
#  ('Пособие', 'Наличие_Отца', 'Село'),
#  ('Пособие', 'Наличие_Отца', 'Иностранец'),
#  ('Пособие', 'Наличие_Отца', 'КодФакультета'),
#  ('Пособие', 'Наличие_Отца', 'СрБаллАттестата'),
#  ('Пособие', 'Наличие_Отца', 'male'),
#  ('Пособие', 'Наличие_Отца', 'female'),
#  ('Пособие', 'Наличие_Отца', 'sex_summ'),
#  ('Пособие', 'Наличие_Отца', 'birth_year_int'),
#  ('Пособие', 'Наличие_Отца', 'basis'),
#  ('Пособие', 'Наличие_Отца', 'language'),
#  ('Пособие', 'Наличие_Отца', 'country'),
#  ('Пособие', 'Наличие_Отца', 'region'),
#  ('Пособие', 'Наличие_Отца', 'city'),
#  ('Пособие', 'Наличие_Отца', 'parents_country'),
#  ('Пособие', 'Опекунство', 'Село'),
#  ('Пособие', 'Опекунство', 'Иностранец'),
#  ('Пособие', 'Опекунство', 'КодФакультета'),
#  ('Пособие', 'Опекунство', 'СрБаллАттестата'),
#  ('Пособие', 'Опекунство', 'male'),
#  ('Пособие', 'Опекунство', 'female'),
#  ('Пособие', 'Опекунство', 'sex_summ'),
#  ('Пособие', 'Опекунство', 'birth_year_int'),
#  ('Пособие', 'Опекунство', 'basis'),
#  ('Пособие', 'Опекунство', 'language'),
#  ('Пособие', 'Опекунство', 'country'),
#  ('Пособие', 'Опекунство', 'region'),
#  ('Пособие', 'Опекунство', 'city'),
#  ('Пособие', 'Опекунство', 'parents_country'),
#  ('Пособие', 'Село', 'Иностранец'),
#  ('Пособие', 'Село', 'КодФакультета'),
#  ('Пособие', 'Село', 'СрБаллАттестата'),
#  ('Пособие', 'Село', 'male'),
#  ('Пособие', 'Село', 'female'),
#  ('Пособие', 'Село', 'sex_summ'),
#  ('Пособие', 'Село', 'birth_year_int'),
#  ('Пособие', 'Село', 'basis'),
#  ('Пособие', 'Село', 'language'),
#  ('Пособие', 'Село', 'country'),
#  ('Пособие', 'Село', 'region'),
#  ('Пособие', 'Село', 'city'),
#  ('Пособие', 'Село', 'parents_country'),
#  ('Пособие', 'Иностранец', 'КодФакультета'),
#  ('Пособие', 'Иностранец', 'СрБаллАттестата'),
#  ('Пособие', 'Иностранец', 'male'),
#  ('Пособие', 'Иностранец', 'female'),
#  ('Пособие', 'Иностранец', 'sex_summ'),
#  ('Пособие', 'Иностранец', 'birth_year_int'),
#  ('Пособие', 'Иностранец', 'basis'),
#  ('Пособие', 'Иностранец', 'language'),
#  ('Пособие', 'Иностранец', 'country'),
#  ('Пособие', 'Иностранец', 'region'),
#  ('Пособие', 'Иностранец', 'city'),
#  ('Пособие', 'Иностранец', 'parents_country'),
#  ('Пособие', 'КодФакультета', 'СрБаллАттестата'),
#  ('Пособие', 'КодФакультета', 'male'),
#  ('Пособие', 'КодФакультета', 'female'),
#  ('Пособие', 'КодФакультета', 'sex_summ'),
#  ('Пособие', 'КодФакультета', 'birth_year_int'),
#  ('Пособие', 'КодФакультета', 'basis'),
#  ('Пособие', 'КодФакультета', 'language'),
#  ('Пособие', 'КодФакультета', 'country'),
#  ('Пособие', 'КодФакультета', 'region'),
#  ('Пособие', 'КодФакультета', 'city'),
#  ('Пособие', 'КодФакультета', 'parents_country'),
#  ('Пособие', 'СрБаллАттестата', 'male'),
#  ('Пособие', 'СрБаллАттестата', 'female'),
#  ('Пособие', 'СрБаллАттестата', 'sex_summ'),
#  ('Пособие', 'СрБаллАттестата', 'birth_year_int'),
#  ('Пособие', 'СрБаллАттестата', 'basis'),
#  ('Пособие', 'СрБаллАттестата', 'language'),
#  ('Пособие', 'СрБаллАттестата', 'country'),
#  ('Пособие', 'СрБаллАттестата', 'region'),
#  ('Пособие', 'СрБаллАттестата', 'city'),
#  ('Пособие', 'СрБаллАттестата', 'parents_country'),
#  ('Пособие', 'male', 'female'),
#  ('Пособие', 'male', 'sex_summ'),
#  ('Пособие', 'male', 'birth_year_int'),
#  ('Пособие', 'male', 'basis'),
#  ('Пособие', 'male', 'language'),
#  ('Пособие', 'male', 'country'),
#  ('Пособие', 'male', 'region'),
#  ('Пособие', 'male', 'city'),
#  ('Пособие', 'male', 'parents_country'),
#  ('Пособие', 'female', 'sex_summ'),
#  ('Пособие', 'female', 'birth_year_int'),
#  ('Пособие', 'female', 'basis'),
#  ('Пособие', 'female', 'language'),
#  ('Пособие', 'female', 'country'),
#  ('Пособие', 'female', 'region'),
#  ('Пособие', 'female', 'city'),
#  ('Пособие', 'female', 'parents_country'),
#  ('Пособие', 'sex_summ', 'birth_year_int'),
#  ('Пособие', 'sex_summ', 'basis'),
#  ('Пособие', 'sex_summ', 'language'),
#  ('Пособие', 'sex_summ', 'country'),
#  ('Пособие', 'sex_summ', 'region'),
#  ('Пособие', 'sex_summ', 'city'),
#  ('Пособие', 'sex_summ', 'parents_country'),
#  ('Пособие', 'birth_year_int', 'basis'),
#  ('Пособие', 'birth_year_int', 'language'),
#  ('Пособие', 'birth_year_int', 'country'),
#  ('Пособие', 'birth_year_int', 'region'),
#  ('Пособие', 'birth_year_int', 'city'),
#  ('Пособие', 'birth_year_int', 'parents_country'),
#  ('Пособие', 'basis', 'language'),
#  ('Пособие', 'basis', 'country'),
#  ('Пособие', 'basis', 'region'),
#  ('Пособие', 'basis', 'city'),
#  ('Пособие', 'basis', 'parents_country'),
#  ('Пособие', 'language', 'country'),
#  ('Пособие', 'language', 'region'),
#  ('Пособие', 'language', 'city'),
#  ('Пособие', 'language', 'parents_country'),
#  ('Пособие', 'country', 'region'),
#  ('Пособие', 'country', 'city'),
#  ('Пособие', 'country', 'parents_country'),
#  ('Пособие', 'region', 'city'),
#  ('Пособие', 'region', 'parents_country'),
#  ('Пособие', 'city', 'parents_country'),
#  ('Общежитие', 'Наличие_Матери', 'Наличие_Отца'),
#  ('Общежитие', 'Наличие_Матери', 'Опекунство'),
#  ('Общежитие', 'Наличие_Матери', 'Село'),
#  ('Общежитие', 'Наличие_Матери', 'Иностранец'),
#  ('Общежитие', 'Наличие_Матери', 'КодФакультета'),
#  ('Общежитие', 'Наличие_Матери', 'СрБаллАттестата'),
#  ('Общежитие', 'Наличие_Матери', 'male'),
#  ('Общежитие', 'Наличие_Матери', 'female'),
#  ('Общежитие', 'Наличие_Матери', 'sex_summ'),
#  ('Общежитие', 'Наличие_Матери', 'birth_year_int'),
#  ('Общежитие', 'Наличие_Матери', 'basis'),
#  ('Общежитие', 'Наличие_Матери', 'language'),
#  ('Общежитие', 'Наличие_Матери', 'country'),
#  ('Общежитие', 'Наличие_Матери', 'region'),
#  ('Общежитие', 'Наличие_Матери', 'city'),
#  ('Общежитие', 'Наличие_Матери', 'parents_country'),
#  ('Общежитие', 'Наличие_Отца', 'Опекунство'),
#  ('Общежитие', 'Наличие_Отца', 'Село'),
#  ('Общежитие', 'Наличие_Отца', 'Иностранец'),
#  ('Общежитие', 'Наличие_Отца', 'КодФакультета'),
#  ('Общежитие', 'Наличие_Отца', 'СрБаллАттестата'),
#  ('Общежитие', 'Наличие_Отца', 'male'),
#  ('Общежитие', 'Наличие_Отца', 'female'),
#  ('Общежитие', 'Наличие_Отца', 'sex_summ'),
#  ('Общежитие', 'Наличие_Отца', 'birth_year_int'),
#  ('Общежитие', 'Наличие_Отца', 'basis'),
#  ('Общежитие', 'Наличие_Отца', 'language'),
#  ('Общежитие', 'Наличие_Отца', 'country'),
#  ('Общежитие', 'Наличие_Отца', 'region'),
#  ('Общежитие', 'Наличие_Отца', 'city'),
#  ('Общежитие', 'Наличие_Отца', 'parents_country'),
#  ('Общежитие', 'Опекунство', 'Село'),
#  ('Общежитие', 'Опекунство', 'Иностранец'),
#  ('Общежитие', 'Опекунство', 'КодФакультета'),
#  ('Общежитие', 'Опекунство', 'СрБаллАттестата'),
#  ('Общежитие', 'Опекунство', 'male'),
#  ('Общежитие', 'Опекунство', 'female'),
#  ('Общежитие', 'Опекунство', 'sex_summ'),
#  ('Общежитие', 'Опекунство', 'birth_year_int'),
#  ('Общежитие', 'Опекунство', 'basis'),
#  ('Общежитие', 'Опекунство', 'language'),
#  ('Общежитие', 'Опекунство', 'country'),
#  ('Общежитие', 'Опекунство', 'region'),
#  ('Общежитие', 'Опекунство', 'city'),
#  ('Общежитие', 'Опекунство', 'parents_country'),
#  ...]

# %%
combinations_frame = pd.DataFrame(all_combinations, columns=range(elements_num))
combinations_frame
# Out:
#                       0                 1                 2          3   \
# 0             Код_группы   Год_Поступления              None       None
# 1             Код_группы  Год_Окончания_УЗ              None       None
# 2             Код_группы           Пособие              None       None
# 3             Код_группы         Общежитие              None       None
# 4             Код_группы    Наличие_Матери              None       None
# ...                  ...               ...               ...        ...
# 4194276       Код_группы   Год_Поступления  Год_Окончания_УЗ  Общежитие
# 4194277       Код_группы   Год_Поступления           Пособие  Общежитие
# 4194278       Код_группы  Год_Окончания_УЗ           Пособие  Общежитие
# 4194279  Год_Поступления  Год_Окончания_УЗ           Пособие  Общежитие
# 4194280       Код_группы   Год_Поступления  Год_Окончания_УЗ    Пособие
#
#                      4               5             6           7           8   \
# 0                  None            None          None        None        None
# 1                  None            None          None        None        None
# 2                  None            None          None        None        None
# 3                  None            None          None        None        None
# 4                  None            None          None        None        None
# ...                 ...             ...           ...         ...         ...
# 4194276  Наличие_Матери    Наличие_Отца    Опекунство        Село  Иностранец
# 4194277  Наличие_Матери    Наличие_Отца    Опекунство        Село  Иностранец
# 4194278  Наличие_Матери    Наличие_Отца    Опекунство        Село  Иностранец
# 4194279  Наличие_Матери    Наличие_Отца    Опекунство        Село  Иностранец
# 4194280       Общежитие  Наличие_Матери  Наличие_Отца  Опекунство        Село
#
#                     9   ...      12        13              14              15  \
# 0                 None  ...    None      None            None            None
# 1                 None  ...    None      None            None            None
# 2                 None  ...    None      None            None            None
# 3                 None  ...    None      None            None            None
# 4                 None  ...    None      None            None            None
# ...                ...  ...     ...       ...             ...             ...
# 4194276  КодФакультета  ...  female  sex_summ  birth_year_int           basis
# 4194277  КодФакультета  ...  female  sex_summ  birth_year_int           basis
# 4194278  КодФакультета  ...  female  sex_summ  birth_year_int           basis
# 4194279  КодФакультета  ...  female  sex_summ  birth_year_int           basis
# 4194280     Иностранец  ...    male    female        sex_summ  birth_year_int
#
#                16        17       18      19               20               21
# 0            None      None     None    None             None             None
# 1            None      None     None    None             None             None
# 2            None      None     None    None             None             None
# 3            None      None     None    None             None             None
# 4            None      None     None    None             None             None
# ...           ...       ...      ...     ...              ...              ...
# 4194276  language   country   region    city  parents_country             None
# 4194277  language   country   region    city  parents_country             None
# 4194278  language   country   region    city  parents_country             None
# 4194279  language   country   region    city  parents_country             None
# 4194280     basis  language  country  region             city  parents_country
#
# [4194281 rows x 22 columns]

# %%
def itter_from_frame(row):
    frame_columns = row.dropna().to_list() + ['Статус']
    frame_to_train = base_df.loc[:, frame_columns]
    return get_accuracy(frame_to_train)

# %%
start, stop = 0, 10
combinations_frame.loc[start:stop, 'accuracy'] = combinations_frame.iloc[start:stop, :].apply(itter_from_frame, axis=1)

# %%
start, stop = 10, 20
combinations_frame.loc[start:stop, 'accuracy'] = combinations_frame.iloc[start:stop, :].apply(itter_from_frame, axis=1)

# %%
combinations_frame.head(30)
# Out:
#                   0                 1     2     3     4     5     6     7  \
# 0        Код_группы   Год_Поступления  None  None  None  None  None  None
# 1        Код_группы  Год_Окончания_УЗ  None  None  None  None  None  None
# 2        Код_группы           Пособие  None  None  None  None  None  None
# 3        Код_группы         Общежитие  None  None  None  None  None  None
# 4        Код_группы    Наличие_Матери  None  None  None  None  None  None
# 5        Код_группы      Наличие_Отца  None  None  None  None  None  None
# 6        Код_группы        Опекунство  None  None  None  None  None  None
# 7        Код_группы              Село  None  None  None  None  None  None
# 8        Код_группы        Иностранец  None  None  None  None  None  None
# 9        Код_группы     КодФакультета  None  None  None  None  None  None
# 10       Код_группы   СрБаллАттестата  None  None  None  None  None  None
# 11       Код_группы              male  None  None  None  None  None  None
# 12       Код_группы            female  None  None  None  None  None  None
# 13       Код_группы          sex_summ  None  None  None  None  None  None
# 14       Код_группы    birth_year_int  None  None  None  None  None  None
# 15       Код_группы             basis  None  None  None  None  None  None
# 16       Код_группы          language  None  None  None  None  None  None
# 17       Код_группы           country  None  None  None  None  None  None
# 18       Код_группы            region  None  None  None  None  None  None
# 19       Код_группы              city  None  None  None  None  None  None
# 20       Код_группы   parents_country  None  None  None  None  None  None
# 21  Год_Поступления  Год_Окончания_УЗ  None  None  None  None  None  None
# 22  Год_Поступления           Пособие  None  None  None  None  None  None
# 23  Год_Поступления         Общежитие  None  None  None  None  None  None
# 24  Год_Поступления    Наличие_Матери  None  None  None  None  None  None
# 25  Год_Поступления      Наличие_Отца  None  None  None  None  None  None
# 26  Год_Поступления        Опекунство  None  None  None  None  None  None
# 27  Год_Поступления              Село  None  None  None  None  None  None
# 28  Год_Поступления        Иностранец  None  None  None  None  None  None
# 29  Год_Поступления     КодФакультета  None  None  None  None  None  None
#
#        8     9  ...    13    14    15    16    17    18    19    20    21  \
# 0   None  None  ...  None  None  None  None  None  None  None  None  None
# 1   None  None  ...  None  None  None  None  None  None  None  None  None
# 2   None  None  ...  None  None  None  None  None  None  None  None  None
# 3   None  None  ...  None  None  None  None  None  None  None  None  None
# 4   None  None  ...  None  None  None  None  None  None  None  None  None
# 5   None  None  ...  None  None  None  None  None  None  None  None  None
# 6   None  None  ...  None  None  None  None  None  None  None  None  None
# 7   None  None  ...  None  None  None  None  None  None  None  None  None
# 8   None  None  ...  None  None  None  None  None  None  None  None  None
# 9   None  None  ...  None  None  None  None  None  None  None  None  None
# 10  None  None  ...  None  None  None  None  None  None  None  None  None
# 11  None  None  ...  None  None  None  None  None  None  None  None  None
# 12  None  None  ...  None  None  None  None  None  None  None  None  None
# 13  None  None  ...  None  None  None  None  None  None  None  None  None
# 14  None  None  ...  None  None  None  None  None  None  None  None  None
# 15  None  None  ...  None  None  None  None  None  None  None  None  None
# 16  None  None  ...  None  None  None  None  None  None  None  None  None
# 17  None  None  ...  None  None  None  None  None  None  None  None  None
# 18  None  None  ...  None  None  None  None  None  None  None  None  None
# 19  None  None  ...  None  None  None  None  None  None  None  None  None
# 20  None  None  ...  None  None  None  None  None  None  None  None  None
# 21  None  None  ...  None  None  None  None  None  None  None  None  None
# 22  None  None  ...  None  None  None  None  None  None  None  None  None
# 23  None  None  ...  None  None  None  None  None  None  None  None  None
# 24  None  None  ...  None  None  None  None  None  None  None  None  None
# 25  None  None  ...  None  None  None  None  None  None  None  None  None
# 26  None  None  ...  None  None  None  None  None  None  None  None  None
# 27  None  None  ...  None  None  None  None  None  None  None  None  None
# 28  None  None  ...  None  None  None  None  None  None  None  None  None
# 29  None  None  ...  None  None  None  None  None  None  None  None  None
#
#     accuracy
# 0   0.750878
# 1   0.694745
# 2   0.739164
# 3   0.745243
# 4   0.739272
# 5   0.757009
# 6   0.757561
# 7   0.721365
# 8   0.748784
# 9   0.750283
# 10  0.658353
# 11  0.741572
# 12  0.733296
# 13  0.748226
# 14  0.696746
# 15  0.740688
# 16  0.753563
# 17  0.765724
# 18  0.719014
# 19  0.702142
# 20       NaN
# 21       NaN
# 22       NaN
# 23       NaN
# 24       NaN
# 25       NaN
# 26       NaN
# 27       NaN
# 28       NaN
# 29       NaN
#
# [30 rows x 23 columns]

# %%
accuracy = {}
for num, columns in enumerate(all_combinations[:100]):
    frame_columns = list(columns)
    frame_columns.append('Статус')
    frame_to_train = base_df.loc[:, frame_columns]
    accuracy[num] = get_accuracy(frame_to_train)
    print(num)
accuracy

# %%
accuracy

# %%
max_index = max(accuracy, key=accuracy.get)
print(max_index, all_combinations[max_index], accuracy[max_index])
